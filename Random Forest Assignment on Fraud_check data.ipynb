# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
fraudcheck=pd.read_csv("D:\\ExcelR Assignments\\Random Forest\\Fraud_check.csv")
fraudcheck.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
fraudcheck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital.Status   600 non-null    object
#  2   Taxable.Income   600 non-null    int64
#  3   City.Population  600 non-null    int64
#  4   Work.Experience  600 non-null    int64
#  5   Urban            600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 28.2+ KB

# %%
fraudcheck=fraudcheck.rename({'Taxable.Income':'TaxInc'},axis=1)
fraudcheck.head()
# Out:
#   Undergrad Marital.Status  TaxInc  City.Population  Work.Experience Urban
# 0        NO         Single   68833            50047               10   YES
# 1       YES       Divorced   33700           134075               18   YES
# 2        NO        Married   36925           160205               30   YES
# 3       YES         Single   50190           193264               15   YES
# 4        NO        Married   81002            27533               28    NO

# %%
fraudcheck["Taxveri"]=fraudcheck.TaxInc.map(lambda x: 'Risky' if x<=30000 else 'Good')
fraudcheck.head()
# Out:
#   Undergrad Marital.Status  TaxInc  City.Population  Work.Experience Urban  \
# 0        NO         Single   68833            50047               10   YES
# 1       YES       Divorced   33700           134075               18   YES
# 2        NO        Married   36925           160205               30   YES
# 3       YES         Single   50190           193264               15   YES
# 4        NO        Married   81002            27533               28    NO
#
#   Taxveri
# 0    Good
# 1    Good
# 2    Good
# 3    Good
# 4    Good

# %%
fraudveri=pd.get_dummies(fraudcheck,columns=['Undergrad','Marital.Status','Urban'])
fraudveri.head()
# Out:
#    TaxInc  City.Population  Work.Experience Taxveri  Undergrad_NO  \
# 0   68833            50047               10    Good             1
# 1   33700           134075               18    Good             0
# 2   36925           160205               30    Good             1
# 3   50190           193264               15    Good             0
# 4   81002            27533               28    Good             1
#
#    Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0              0                        0                       0
# 1              1                        1                       0
# 2              0                        0                       1
# 3              1                        0                       0
# 4              0                        0                       1
#
#    Marital.Status_Single  Urban_NO  Urban_YES
# 0                      1         0          1
# 1                      0         0          1
# 2                      0         0          1
# 3                      1         0          1
# 4                      0         1          0

# %%
fraudveri["Taxveri"].value_counts()
# Out:
# Good     476
# Risky    124
# Name: Taxveri, dtype: int64

# %%
labelencoder=LabelEncoder()
fraudveri["Taxveri"]=labelencoder.fit_transform(fraudveri["Taxveri"])
fraudveri.head()
# Out:
#    TaxInc  City.Population  Work.Experience  Taxveri  Undergrad_NO  \
# 0   68833            50047               10        0             1
# 1   33700           134075               18        0             0
# 2   36925           160205               30        0             1
# 3   50190           193264               15        0             0
# 4   81002            27533               28        0             1
#
#    Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0              0                        0                       0
# 1              1                        1                       0
# 2              0                        0                       1
# 3              1                        0                       0
# 4              0                        0                       1
#
#    Marital.Status_Single  Urban_NO  Urban_YES
# 0                      1         0          1
# 1                      0         0          1
# 2                      0         0          1
# 3                      1         0          1
# 4                      0         1          0

# %% [markdown]
# # Random Forest Model

# %%
columns=['City.Population','Work.Experience','Undergrad_NO','Undergrad_YES','Marital.Status_Divorced','Marital.Status_Married','Marital.Status_Single','Urban_NO','Urban_YES']

# %%
X=fraudveri[columns]
Y=fraudveri["Taxveri"]

# %%
kfold=KFold(n_splits=6,random_state=18,shuffle=True)
model=RandomForestClassifier(n_estimators=20,max_features=4)
results=cross_val_score(model,X,Y,cv=kfold)

# %%
results.mean()*100
# Out:
# 75.66666666666667
